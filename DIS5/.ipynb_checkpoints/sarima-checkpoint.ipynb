# %%
import pandas as pd

file_path = 'Bitcoin Historical Data.csv'
bitcoin_data = pd.read_csv(file_path)

bitcoin_data.head()
# Out:
#          Date     Price      Open      High       Low     Vol. Change %
# 0  06/02/2024  69,129.8  67,760.8  70,131.0  67,330.6   63.35K    2.02%
# 1  05/26/2024  67,760.8  69,287.2  70,638.3  66,676.8  385.09K   -2.20%
# 2  05/19/2024  69,284.4  66,919.0  71,872.0  65,937.3  534.40K    3.54%
# 3  05/12/2024  66,917.5  60,826.6  67,420.7  60,647.1  469.69K   10.01%
# 4  05/05/2024  60,826.6  63,897.7  65,448.8  60,251.8  455.08K   -4.79%

# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.stattools import adfuller
import matplotlib.pyplot as plt

data = pd.read_csv('Bitcoin Historical Data.csv')
data['Date'] = pd.to_datetime(data['Date'])
data['Price'] = data['Price'].str.replace(',', '').astype(float)
data.set_index('Date', inplace=True)
data.sort_index(inplace=True)
price_data = data['Price']

price_data_log = np.log(price_data)

price_data_train_log = price_data_log[:'2022']

result = adfuller(price_data_train_log.dropna())
print('ADF Statistic:', result[0])
print('p-value:', result[1])

model = SARIMAX(price_data_train_log,
                order=(1, 1, 1),
                seasonal_order=(1, 1, 1, 208),  
                enforce_stationarity=False,
                enforce_invertibility=False)

fitted_model = model.fit(disp=False)
print(fitted_model.summary())
# Out:
# ADF Statistic: -2.8948030316590465
# p-value: 0.045955680421265965
# C:\Users\RYZEN9\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# C:\Users\RYZEN9\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# C:\Users\RYZEN9\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
#                                       SARIMAX Results
# ...

# %%
forecast = fitted_model.get_forecast(steps=102)
forecast_index = pd.date_range(start=price_data_train_log.index[-1], periods=103, freq='W')[1:]
forecast_series = pd.Series(forecast.predicted_mean.values, index=forecast_index)

forecast_series_original_scale = np.exp(forecast_series)

plt.figure(figsize=(10, 6))
plt.plot(price_data, label='Historical Weekly Prices')
plt.plot(forecast_series_original_scale, label='Forecasted Prices')
plt.title('Bitcoin Price Forecast')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
forecast = fitted_model.get_forecast(steps=260)
forecast_index = pd.date_range(start=price_data_train_log.index[-1], periods=261, freq='W')[1:]
forecast_series = pd.Series(forecast.predicted_mean.values, index=forecast_index)

forecast_series_original_scale = np.exp(forecast_series)

plt.figure(figsize=(10, 6))
plt.plot(price_data, label='Historical Weekly Prices')
plt.plot(forecast_series_original_scale, label='Forecasted Prices')
plt.title('Bitcoin Price Forecast')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
forecast = fitted_model.get_forecast(steps=260)
forecast_index = pd.date_range(start=price_data_train_log.index[-1], periods=261, freq='W')[1:]
forecast_series = pd.Series(forecast.predicted_mean.values, index=forecast_index)

forecast_series_original_scale = np.exp(forecast_series)

plt.figure(figsize=(14, 7))

# Подграфик для логарифмических цен
plt.subplot(2, 1, 1)
plt.plot(price_data_log, label='Historical Weekly Log Prices')
plt.plot(forecast_series, label='Forecasted Log Prices')
plt.title('Bitcoin Log Price Forecast')
plt.xlabel('Date')
plt.ylabel('Log Price')
plt.legend()

# Подграфик для реальных цен
plt.subplot(2, 1, 2)
plt.plot(price_data, label='Historical Weekly Prices')
plt.plot(forecast_series_original_scale, label='Forecasted Prices')
plt.title('Bitcoin Price Forecast')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()

plt.tight_layout()
plt.show()
